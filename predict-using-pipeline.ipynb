# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('/content/pipe.pkl','rb'))

# %%
# Assume user input
import pandas as pd

df = pd.DataFrame([{
    'Pclass': 2,
    'Sex': 'male',
    'Age': 31.0,
    'SibSp': 0,
    'Parch': 0,
    'Fare': 10.5,
    'Embarked': 'S'
}])

prediction = pipe.predict(df)
print("Prediction:", prediction)
# Out:
# Prediction: [0]
