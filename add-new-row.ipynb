# %%
import pandas as pd
import requests

url = "https://anapioficeandfire.com/api/books/1"

headers = {
	"x-rapidapi-key": "49f298381fmsh677f6879aa526bfp1df327jsnc79a37638e35",
	"x-rapidapi-host": "linkedin-bulk-data-scraper.p.rapidapi.com"
}

response = requests.get("https://anapioficeandfire.com/api/books/1", headers=headers)
data = response.json()
df = pd.DataFrame([{
    "name": data["name"],
    "isbn": data["isbn"],
    "pages": data["numberOfPages"],
    "released": data["released"],
    "url": data["url"]
}])
df
# Out:
#                 name            isbn  pages             released  \
# 0  A Game of Thrones  978-0553103540    694  1996-08-01T00:00:00
#
#                                          url
# 0  https://anapioficeandfire.com/api/books/1

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
import requests
import pandas as pd

headers = {"Accept": "application/json"}

rows = []

for i in range(1, 694):
    url = f"https://anapioficeandfire.com/api/books/{i}"
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        data = response.json()

        # add a row from the fields you want
        rows.append({
            "name": data.get("name"),
            "isbn": data.get("isbn"),
            "pages": data.get("numberOfPages"),
            "released": data.get("released"),
            "publisher": data.get("publisher"),
            "url": data.get("url")
        })

# convert to DataFrame
df = pd.DataFrame(rows)
df
# Out:
#                               name            isbn  pages  \
# 0                A Game of Thrones  978-0553103540    694
# 1                 A Clash of Kings  978-0553108033    768
# 2                A Storm of Swords  978-0553106633    992
# 3                 The Hedge Knight  978-0976401100    164
# 4                A Feast for Crows  978-0553801507    784
# 5                  The Sworn Sword  978-0785126508    152
# 6               The Mystery Knight  978-0765360267    416
# 7             A Dance with Dragons  978-0553801477   1040
# 8       The Princess and the Queen  978-0765332066    784
# 9                 The Rogue Prince  978-0345537263    832
# 10       The World of Ice and Fire  978-0553805444    336
# 11  A Knight of the Seven Kingdoms  978-0345533487    368
#
#                released                  publisher  \
# 0   1996-08-01T00:00:00               Bantam Books
# 1   1999-02-02T00:00:00               Bantam Books
# 2   2000-10-31T00:00:00               Bantam Books
# ...

# %%
df.shape
# Out:
# (12, 6)

# %%
df.to_csv('movies.csv')
