# %%
import pandas as pd
import seaborn as sns

# %%
tips = sns.load_dataset('/content/archive (1).zip')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1702453646.py in <cell line: 0>()
# ----> 1 tips = sns.load_dataset('/content/tips.zip')
#
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     571         if not os.path.exists(cache_path):
#     572             if name not in get_dataset_names():
# --> 573                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     574             urlretrieve(url, cache_path)
#     575         full_path = cache_path
#
# ValueError: '/content/tips.zip' is not one of the example datasets.

# %%
titanic = pd.read_csv('/content/titanic.zip')

# %%
flights = sns.load_dataset('/content/flights.zip')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1549994060.py in <cell line: 0>()
# ----> 1 flights = sns.load_dataset('/content/flights.zip')
#
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     571         if not os.path.exists(cache_path):
#     572             if name not in get_dataset_names():
# --> 573                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     574             urlretrieve(url, cache_path)
#     575         full_path = cache_path
#
# ValueError: '/content/flights.zip' is not one of the example datasets.

# %%
iris = sns.load_dataset('/content/iris.zip')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1109833134.py in <cell line: 0>()
# ----> 1 iris = sns.load_dataset('/content/iris.zip')
#
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     571         if not os.path.exists(cache_path):
#     572             if name not in get_dataset_names():
# --> 573                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     574             urlretrieve(url, cache_path)
#     575         full_path = cache_path
#
# ValueError: '/content/iris.zip' is not one of the example datasets.
